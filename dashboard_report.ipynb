# %% [markdown]
# # **Steam Games Insights Dashboard - MongoDB Analysis and Managerial Insights**
#
# **Group 20**
#
# **Prachi Lakra (055029)**
#
# **Priyanka Goyal (055034)**

# %% [markdown]
# ### **Objective**
# This project aimed to develop an interactive dashboard using data stored in MongoDB, offering valuable insights into the gaming industry. The dashboard provides visualizations of key metrics such as game pricing, memory requirements, developer influence, and other significant factors.
#
# ### **Dataset Overview**
# The dataset, sourced from Steam, a leading gaming platform, contains comprehensive details on games, including pricing, system requirements, popularity metrics, and developer data.
#
# #### **1. Dataset Features**
# ##### **Game Details**
# - **Game Name:** Title of the game.
# - **Genre:** Category or type of game (e.g., Action, Adventure, Simulation).
# - **Release Date:** The year and date a game was launched on Steam.
#
# ##### **Pricing Information**
# - **Maximum Price:** The highest price for a game.
# - **Average Price:** The mean price across the dataset.
# - **Yearly Pricing Trends:** A historical analysis of pricing fluctuations over time.
#
# ##### **System Requirements**
# - **Minimum RAM:** The least amount of memory required to run the game, categorized by operating systems:
#   - Windows
#   - Linux
#   - MacOS
# - **Recommended RAM:** The suggested memory for optimal gameplay, categorized by OS:
#   - Windows
#   - Linux
#   - MacOS
#
# ##### **Popularity Metrics**
# - **Popular Tags:** Metadata describing game features (e.g., "Multiplayer," "Singleplayer").
# - **PEGI Ratings:** Official classifications from the Pan-European Game Information system, categorizing games based on age-appropriateness.
# - **Popularity Word Cloud:** A visual representation of commonly associated tags and genres.
#
# ##### **Developer Information**
# - **Developers:** Companies or studios responsible for game creation.
# - **Famous Developers:** Highlighting top studios based on game output and popularity.
#
# ##### **Platform-Specific Details**
# - **System Compatibility:** Information on game compatibility with Windows, Linux, and MacOS.
#
# #### **2. PEGI Ratings and Their Importance**
# The dataset includes PEGI ratings, which help in:
# - **Regulatory Compliance:** Ensuring games align with industry standards.
# - **Parental Guidance:** Assisting parents in making informed gaming choices.
# - **Market Analysis:** Identifying audience segments based on content ratings.
#
# ##### **Key PEGI Classifications in the Dataset**
# - **PEGI 3:** Suitable for all ages.
# - **PEGI 7:** Includes mild violence or potentially scary scenes.
# - **PEGI 12:** Features moderate violence or mild suggestive content.
# - **PEGI 16:** Contains realistic violence, drug use, or mature themes.
# - **PEGI 18:** Features explicit violence, adult content, and strong language.
#
# These ratings allow for trend analysis in game development and marketing strategies.
#
# #### **3. Key Dataset Statistics**
# - **Total Games Analyzed:** 21,000 unique game entries.
# - **Pricing Insights:**
#   - **Minimum Price:** $0 (free-to-play games)
#   - **Maximum Price:** $999 (premium editions, collector bundles)
#   - **Average Price:** $445.11
# - **System Requirements:**
#   - Minimum RAM varies from 2 GB to 8 GB, depending on the OS.
#   - Recommended RAM is typically 8 GB for Windows and MacOS, 4 GB for Linux.
#
# ### **Dashboard Insights**
# #### **Game Insights**
# - **Unique Games:** The dataset features 6,746 unique titles, reflecting a wide variety of games.
# - **Average Price:** The mean price of $445.11 suggests the presence of high-end games and collector's editions.
# - **Total Games Count:** 21,000 games analyzed across various platforms.
# - **Peak Game Price:** The highest listed price is $999, often associated with special editions.
#
# #### **Memory Requirements Across OS**
# - **Windows:** Most games require 8 GB RAM for smooth performance.
# - **Linux:** Optimized for 4 GB RAM, making it more accessible for lower-end devices.
# - **MacOS:** Aligns with Windows, requiring 8 GB RAM.
#
# #### **Pricing Trends Over Time**
# - **Historical Price Evolution:** A steady rise in game prices is observed, with recent years seeing sharper increases.
# - **Yearly Average Price:** Peaks correspond to major game releases or bundled deals.
#
# #### **Popularity and Developer Analysis**
# - **Common PEGI Tags:** High prevalence of tags such as "Violence" and "Blood" highlights the popularity of action games.
# - **Popular Game Tags:** "Multiplayer," "Action," and "Singleplayer" dominate, indicating diverse player preferences.
# - **Famous Developers:** "Paradox Development Studio" and "Dovetail Games" are among the most prominent in the dataset.
# - **Recognizable PC Games:** "Conan Exiles" and "Path of Exile" stand out as popular titles.
#
# ### **Learnings from MongoDB Dashboard Development**
# ##### **Data Structuring and Aggregation**
# - Effective schema design in MongoDB is crucial for handling diverse datasets.
# - Utilized aggregation pipelines for computing metrics such as average prices and RAM distributions.
# - Optimized queries using indexing for better performance.
#
# ##### **Data Cleaning and Transformation**
# - Standardized RAM values and price formats to ensure consistency.
# - Addressed missing values during data import.
#
# ##### **Integration with Visualization Tools**
# - Connected MongoDB to Python-based frameworks for creating dynamic dashboards.
# - Developed real-time queries for rapid data retrieval.
#
# ### **Managerial Insights Gained**
# ##### **Market Segmentation**
# - **Insight:** RAM requirements indicate segmentation between casual and serious gamers.
# - **Decision:** Develop games that cater to both budget-conscious and high-end users.
#
# ##### **Pricing Strategies**
# - **Insight:** Wide price variations suggest potential for tiered pricing models.
# - **Decision:** Offer standard, premium, and collector’s editions to attract different buyers.
#
# ##### **Gaming Trends**
# - **Insight:** Increasing game prices and system requirements suggest a shift towards high-quality, resource-intensive games.
# - **Decision:** Invest in cutting-edge technology to meet evolving consumer expectations.
#
# ##### **Content Preferences**
# - **Insight:** The dominance of "Multiplayer" and "Singleplayer" tags shows demand for both social and solo experiences.
# - **Decision:** Develop hybrid games with flexible play modes.
#
# ##### **Developer Influence**
# - **Insight:** Certain studios have a strong market presence.
# - **Decision:** Smaller developers can explore partnerships, while major studios should diversify their portfolios.
#
# ##### **Platform Optimization**
# - **Insight:** System requirements differ across Windows, Linux, and MacOS.
# - **Decision:** Optimize game performance for multiple platforms to enhance accessibility.
#
# ##### **Affordability Considerations**
# - **Insight:** High average game prices may limit access for budget gamers.
# - **Decision:** Introduce affordable versions or discounts to widen market reach.
#
# ##### **Regulatory Compliance**
# - **Insight:** PEGI ratings indicate the necessity of adhering to content regulations.
# - **Decision:** Ensure compliance to avoid legal issues and improve market credibility.
#
# ### **Future Scope**
# - **Enhanced Data Exploration:** Include regional insights and genre-specific trends.
# - **Predictive Analytics:** Apply machine learning to forecast pricing and system requirements.
# - **User-Centric Enhancements:** Introduce real-time filters for improved data exploration.
# - **Monetization Insights:** Integrate sales data for analyzing profitability trends.
#
# This project provides a comprehensive understanding of the gaming industry through data-driven insights, offering valuable recommendations for developers, marketers, and business strategists.

# %% [markdown]
# # **Dashboard**
#
#
# ![Game Insights Dashboard.png](data:image/png;base64,...)
